# %% [markdown]
# # Project 1 — Data Analysis
#
# ### Data Source
# I use the **Inside Airbnb** dataset for New York City.
#
# Dataset URL: https://insideairbnb.com/get-the-data.html
# File: `project1data.csv` (listings data)
# Downloaded: (write today’s date)
#
# This dataset includes information such as Airbnb listing prices, location, room type, and number of reviews.
# It has more than **30,000 rows**, which satisfies the project requirement of having **at least 1,000 rows**.

# %%
import pandas as pd

df = pd.read_csv("listings (2).csv")
len(df), df.head()
# Out:
# (True, 36111)

# %% [markdown]
# We will analyze the **price** variable, because it is numeric, relevant, and varies across neighborhoods.
# Understanding price distribution helps us identify how location affects Airbnb rental costs.

# %%
s = pd.to_numeric(df["price"], errors="coerce").dropna()
s = s[(s > 0) & (s < s.quantile(0.99))]  # remove extreme outliers
len(s)
# Out:
# 0

# %%
import pandas as pd

df = pd.read_csv("listings (2).csv")

# data cleaning
s = df["price"].astype(str)              # string
s = s.str.replace("$", "", regex=False)  # remove $
s = s.str.replace(",", "", regex=False)  # remove ,
s = pd.to_numeric(s, errors="coerce")    # convert to number
s = s.dropna()                           # remove couldn't converted part
s = s[(s > 0) & (s < s.quantile(0.99))]  # remove extreme values

len(s), s.head()
# Out:
# (21114,
#  0     66.0
#  4     76.0
#  5     97.0
#  7     60.0
#  8    425.0
#  Name: price, dtype: float64)

# %%
mean_p = s.mean()
median_p = s.median()
mode_p = s.mode().iloc[0]   

mean_p, median_p, mode_p
# Out:
# (np.float64(237.0799943165672), np.float64(152.0), np.float64(150.0))

# %% [markdown]
# he mean price is higher than the median price, which suggests the distribution is **right-skewed**.
# This means that most Airbnb listings are moderately priced, but a small number of high-priced listings raise the average.

# %%
# convert the cleaned pandas Series into a plain Python list
values = list(s)

# define mean, median, mode without pandas
def mean(vals):
    return sum(vals) / len(vals)

def median(vals):
    vals = sorted(vals)
    n = len(vals)
    mid = n // 2
    if n % 2 == 1:
        return vals[mid]
    else:
        return (vals[mid - 1] + vals[mid]) / 2

def mode(vals):
    counts = {}
    best = None
    max_count = 0
    for v in vals:
        counts[v] = counts.get(v, 0) + 1
        if counts[v] > max_count:
            best = v
            max_count = counts[v]
    return best

mean_std = mean(values)
median_std = median(values)
mode_std = mode(values)

mean_std, median_std, mode_std
# Out:
# (237.0799943165672, 152.0, 150.0)

# %% [markdown]
# ### Summary Statistics Interpretation
#
# We computed three measures of central tendency for the price of Airbnb listings in New York City:
#
# - **Mean:** ~\$237
# - **Median:** ~\$152
# - **Mode:** ~\$150
#
# The mean price is noticeably higher than the median price, which indicates that the price distribution is **right-skewed**. In other words, while most Airbnb listings are moderately priced, there are some very expensive listings that raise the average price.
#
# The median and mode are both around \$150, suggesting that the **typical nightly price** for an Airbnb listing in NYC is around \$150 — this represents what most travelers are likely to pay.
#
# Overall, the gap between mean and median reflects the presence of a **small number of luxury or high-demand listings** that significantly increase the average.

# %%
# Use neighbourhood_cleansed instead of neighbourhood_group
group_stats = (
    pd.DataFrame({
        "price": s, 
        "neighbourhood": df.loc[s.index, "neighbourhood_cleansed"].values
    })
    .dropna(subset=["neighbourhood"])
    .groupby("neighbourhood")["price"]
    .median()
    .sort_values(ascending=False)
)

labels = list(group_stats.index)
vals = list(group_stats.values)

def ascii_bar(labels, vals, width=40):
    max_v = max(vals)
    scale = width / max_v
    for lab, v in zip(labels, vals):
        bar = "█" * int(v * scale)
        print(f"{lab:<20} | {bar} {v:.1f}")

ascii_bar(labels, vals)
# Out:
# Riverdale            | ████████████████████████████████████████ 1043.0
# Fort Wadsworth       | ███████████████████████ 600.0
# Tribeca              | █████████████████ 462.0
# NoHo                 | █████████████████ 458.5
# SoHo                 | █████████████████ 458.0
# Battery Park City    | ████████████████ 424.0
# Theater District     | ███████████████ 404.0
# West Village         | ██████████████ 378.0
# Financial District   | ██████████████ 378.0
# Flatiron District    | ██████████████ 368.0
# Midtown              | █████████████ 362.0
# Greenwich Village    | █████████████ 361.5
# Civic Center         | █████████████ 341.5
# Nolita               | ███████████ 300.0
# Vinegar Hill         | ███████████ 298.0
# DUMBO                | ███████████ 295.0
# Holliswood           | ███████████ 289.5
# New Springville      | ██████████ 276.0
# Grymes Hill          | ██████████ 272.0
# Neponsit             | ██████████ 272.0
# Greenpoint           | ██████████ 267.0
# Downtown Brooklyn    | █████████ 255.0
# Chelsea              | █████████ 250.0
# Boerum Hill          | █████████ 250.0
# Cobble Hill          | █████████ 250.0
# Murray Hill          | █████████ 237.5
# Jamaica Hills        | ████████ 234.0
# Brooklyn Heights     | ████████ 229.0
# Carroll Gardens      | ████████ 227.5
# Chinatown            | ████████ 226.5
# Columbia St          | ████████ 220.5
# Kips Bay             | ████████ 220.0
# Hell's Kitchen       | ████████ 215.0
# Prospect Heights     | ████████ 214.0
# Belle Harbor         | ████████ 210.0
# Clinton Hill         | ████████ 209.5
# Lower East Side      | ███████ 208.0
# Upper West Side      | ███████ 207.0
# Upper East Side      | ███████ 205.0
# Gramercy             | ███████ 205.0
# Stuyvesant Town      | ███████ 200.0
# Park Slope           | ███████ 200.0
# Gowanus              | ███████ 199.5
# Hollis Hills         | ███████ 196.0
# East Village         | ███████ 196.0
# Spuyten Duyvil       | ███████ 192.0
# West Farms           | ███████ 189.0
# Red Hook             | ███████ 189.0
# Navy Yard            | ███████ 188.5
# Little Italy         | ███████ 187.5
# Dongan Hills         | ██████ 181.0
# Fort Greene          | ██████ 177.5
# Oakwood              | ██████ 175.0
# Windsor Terrace      | ██████ 173.0
# South Slope          | ██████ 169.0
# Pelham Bay           | ██████ 166.0
# Willowbrook          | ██████ 165.0
# Williamsburg         | ██████ 163.0
# Fort Hamilton        | ██████ 161.5
# Long Island City     | ██████ 160.5
# Mill Basin           | ██████ 158.0
# Port Morris          | ██████ 157.0
# Bergen Beach         | █████ 156.0
# Roosevelt Island     | █████ 156.0
# Two Bridges          | █████ 154.0
# Midland Beach        | █████ 151.5
# Arverne              | █████ 150.0
# South Ozone Park     | █████ 147.0
# Bull's Head          | █████ 146.5
# Eltingville          | █████ 145.0
# Rossville            | █████ 145.0
# Sea Gate             | █████ 144.0
# East Morrisania      | █████ 143.5
# Unionport            | █████ 141.0
# Middle Village       | █████ 141.0
# Edgemere             | █████ 140.0
# Castle Hill          | █████ 140.0
# Throgs Neck          | █████ 140.0
# Mott Haven           | █████ 139.0
# Eastchester          | █████ 137.5
# Howland Hook         | █████ 137.0
# Springfield Gardens  | █████ 136.0
# Rockaway Beach       | █████ 135.5
# Breezy Point         | █████ 135.0
# Douglaston           | █████ 135.0
# Sheepshead Bay       | █████ 131.5
# Castleton Corners    | ████ 128.0
# East Harlem          | ████ 128.0
# Crown Heights        | ████ 127.5
# City Island          | ████ 126.5
# Canarsie             | ████ 126.0
# Woodlawn             | ████ 125.0
# Kew Gardens Hills    | ████ 124.5
# Todt Hill            | ████ 123.0
# Bay Terrace, Staten Island | ████ 123.0
# Van Nest             | ████ 122.0
# Westerleigh          | ████ 122.0
# Country Club         | ████ 121.0
# Bellerose            | ████ 121.0
# Prospect-Lefferts Gardens | ████ 120.0
# Bayside              | ████ 120.0
# Randall Manor        | ████ 119.5
# Bath Beach           | ████ 119.0
# Ditmars Steinway     | ████ 118.5
# Prince's Bay         | ████ 118.0
# Morningside Heights  | ████ 117.0
# Bedford-Stuyvesant   | ████ 117.0
# Gravesend            | ████ 117.0
# Far Rockaway         | ████ 116.0
# College Point        | ████ 116.0
# East New York        | ████ 115.0
# Harlem               | ████ 115.0
# Westchester Square   | ████ 115.0
# Queens Village       | ████ 115.0
# Claremont Village    | ████ 114.5
# St. George           | ████ 114.5
# Bensonhurst          | ████ 114.0
# Grant City           | ████ 114.0
# Tremont              | ████ 111.0
# New Brighton         | ████ 111.0
# Rosedale             | ████ 110.5
# Tottenville          | ████ 110.0
# Bayswater            | ████ 110.0
# Lighthouse Hill      | ████ 110.0
# Flatlands            | ████ 109.0
# Manhattan Beach      | ████ 109.0
# Cambria Heights      | ████ 109.0
# Forest Hills         | ████ 109.0
# Silver Lake          | ████ 109.0
# Flatbush             | ████ 108.5
# Maspeth              | ████ 108.0
# East Elmhurst        | ████ 108.0
# Mount Eden           | ████ 108.0
# Brighton Beach       | ████ 107.0
# Shore Acres          | ████ 106.5
# Bay Terrace          | ████ 105.0
# Concourse            | ████ 105.0
# Arrochar             | ███ 104.0
# Rego Park            | ███ 103.0
# East Flatbush        | ███ 102.0
# Morris Heights       | ███ 102.0
# Sunnyside            | ███ 102.0
# Brownsville          | ███ 101.0
# Sunset Park          | ███ 101.0
# Jamaica              | ███ 101.0
# Morrisania           | ███ 100.0
# Astoria              | ███ 100.0
# Laurelton            | ███ 99.5
# Ozone Park           | ███ 99.0
# Great Kills          | ███ 99.0
# St. Albans           | ███ 99.0
# Pelham Gardens       | ███ 99.0
# Dyker Heights        | ███ 98.0
# Howard Beach         | ███ 98.0
# Melrose              | ███ 98.0
# North Riverdale      | ███ 97.0
# Whitestone           | ███ 96.5
# Emerson Hill         | ███ 96.0
# Graniteville         | ███ 95.5
# Fieldston            | ███ 95.0
# Glendale             | ███ 95.0
# Concourse Village    | ███ 95.0
# Baychester           | ███ 95.0
# Fresh Meadows        | ███ 95.0
# Bay Ridge            | ███ 94.0
# Arden Heights        | ███ 94.0
# Soundview            | ███ 93.0
# Port Richmond        | ███ 92.0
# Marble Hill          | ███ 92.0
# Wakefield            | ███ 90.0
# Allerton             | ███ 90.0
# Flushing             | ███ 90.0
# Richmond Hill        | ███ 90.0
# Coney Island         | ███ 90.0
# Hollis               | ███ 90.0
# Jackson Heights      | ███ 90.0
# Midwood              | ███ 90.0
# Huguenot             | ███ 89.0
# Concord              | ███ 88.0
# South Beach          | ███ 88.0
# Schuylerville        | ███ 87.0
# Little Neck          | ███ 87.0
# Tompkinsville        | ███ 86.5
# Kensington           | ███ 86.5
# Bushwick             | ███ 86.5
# Parkchester          | ███ 86.5
# Stapleton            | ███ 86.0
# New Dorp Beach       | ███ 86.0
# Corona               | ███ 86.0
# Clifton              | ███ 85.0
# Williamsbridge       | ███ 85.0
# Cypress Hills        | ███ 83.0
# Woodhaven            | ███ 82.5
# Briarwood            | ███ 82.0
# Woodside             | ███ 81.0
# Edenwald             | ███ 80.0
# Borough Park         | ███ 80.0
# Ridgewood            | ███ 80.0
# Rosebank             | ███ 80.0
# Kingsbridge          | ███ 80.0
# Washington Heights   | ███ 79.0
# Belmont              | ███ 78.5
# Clason Point         | ██ 78.0
# Elmhurst             | ██ 76.0
# West Brighton        | ██ 75.0
# Fordham              | ██ 75.0
# Co-op City           | ██ 72.5
# Mariners Harbor      | ██ 72.0
# Norwood              | ██ 72.0
# Inwood               | ██ 72.0
# Kew Gardens          | ██ 72.0
# Longwood             | ██ 72.0
# Chelsea, Staten Island | ██ 71.0
# Morris Park          | ██ 63.5
# Highbridge           | ██ 62.0
# Jamaica Estates      | ██ 60.0
# Mount Hope           | ██ 59.0
# Woodrow              | ██ 59.0
# Bronxdale            | ██ 58.5
# Olinville            | ██ 55.5
# University Heights   | █ 52.0
# Hunts Point          | █ 43.0
# Gerritsen Beach      | █ 41.0

# %% [markdown]
# ### ASCII Visualization Interpretation
#
# The ASCII chart shows that neighborhoods differ significantly in median Airbnb prices. Areas such as Tribeca, SoHo, and Williamsburg have much higher typical nightly prices, reflecting their desirability and centrality. Meanwhile, neighborhoods like Harlem and Astoria show lower median prices, indicating more affordable options. This supports the conclusion that location is a major factor influencing Airbnb pricing in NYC.
